# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-80.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)
len(coordinates)
# Out:
# 2000

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 830

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0c15f3f7ad147dd529de53f3749c2596

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []


# Create counters and set them to 1
record_count = 1
set_count = 1


# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
    
    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1
    
    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()

        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]     
        weather_description = city_weather["weather"][0]["description"]
        # Append the city information into the city_data list
        # city_data.append({"City": city.title(),
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": weather_description})
    
    #If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | hithadhoo
# Processing Record 2 of Set 1 | dikson
# Processing Record 3 of Set 1 | brokopondo
# Processing Record 4 of Set 1 | bredasdorp
# Processing Record 5 of Set 1 | formoso do araguaia
# City not found. Skipping...
# Processing Record 6 of Set 1 | katsuura
# Processing Record 7 of Set 1 | salsomaggiore terme
# Processing Record 8 of Set 1 | east london
# Processing Record 9 of Set 1 | nikolskoye
# Processing Record 10 of Set 1 | hasaki
# Processing Record 11 of Set 1 | ribeira grande
# Processing Record 12 of Set 1 | bollnas
# Processing Record 13 of Set 1 | bambous virieux
# Processing Record 14 of Set 1 | arraial do cabo
# Processing Record 15 of Set 1 | mahebourg
# Processing Record 16 of Set 1 | roebourne
# Processing Record 17 of Set 1 | husavik
# Processing Record 18 of Set 1 | hobart
# Processing Record 19 of Set 1 | hobyo
# Processing Record 20 of Set 1 | butaritari
# Processing Record 21 of Set 1 | waingapu
# Processing Record 22 of Set 1 | bluff
# Processing Record 23 of Set 1 | perelyub
# Processing Record 24 of Set 1 | jamestown
# Processing Record 25 of Set 1 | skalistyy
# City not found. Skipping...
# Processing Record 26 of Set 1 | hermanus
# Processing Record 27 of Set 1 | souillac
# Processing Record 28 of Set 1 | albany
# Processing Record 29 of Set 1 | qaanaaq
# Processing Record 30 of Set 1 | svetlogorsk
# Processing Record 31 of Set 1 | xining
# Processing Record 32 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 33 of Set 1 | yerbogachen
# Processing Record 34 of Set 1 | bougouni
# Processing Record 35 of Set 1 | severo-kurilsk
# Processing Record 36 of Set 1 | carutapera
# Processing Record 37 of Set 1 | perama
# Processing Record 38 of Set 1 | cape town
# Processing Record 39 of Set 1 | alice springs
# Processing Record 40 of Set 1 | new norfolk
# Processing Record 41 of Set 1 | aljezur
# Processing Record 42 of Set 1 | villa carlos paz
# Processing Record 43 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 1 | ushuaia
# Processing Record 45 of Set 1 | moose factory
# Processing Record 46 of Set 1 | borogontsy
# Processing Record 47 of Set 1 | jabinyanah
# Processing Record 48 of Set 1 | weligama
# Processing Record 49 of Set 1 | lashio
# Processing Record 50 of Set 1 | chokurdakh
# Processing Record 1 of Set 2 | saint george
# Processing Record 2 of Set 2 | arys
# Processing Record 3 of Set 2 | cabra
# Processing Record 4 of Set 2 | japura
# Processing Record 5 of Set 2 | georgetown
# Processing Record 6 of Set 2 | shangrao
# Processing Record 7 of Set 2 | carnarvon
# Processing Record 8 of Set 2 | busselton
# Processing Record 9 of Set 2 | virginia beach
# Processing Record 10 of Set 2 | trairi
# Processing Record 11 of Set 2 | wittingen
# Processing Record 12 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 13 of Set 2 | karratha
# Processing Record 14 of Set 2 | denpasar
# Processing Record 15 of Set 2 | bengkulu
# Processing Record 16 of Set 2 | gazojak
# Processing Record 17 of Set 2 | tuatapere
# Processing Record 18 of Set 2 | krasnoselkup
# Processing Record 19 of Set 2 | sopelana
# Processing Record 20 of Set 2 | caravelas
# Processing Record 21 of Set 2 | port alfred
# Processing Record 22 of Set 2 | nizhnyaya poyma
# Processing Record 23 of Set 2 | awjilah
# Processing Record 24 of Set 2 | sao filipe
# Processing Record 25 of Set 2 | nelson bay
# Processing Record 26 of Set 2 | aleksandriya
# Processing Record 27 of Set 2 | kavieng
# Processing Record 28 of Set 2 | khatanga
# Processing Record 29 of Set 2 | san rafael
# Processing Record 30 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 2 | kaitangata
# Processing Record 32 of Set 2 | kamenka
# Processing Record 33 of Set 2 | manono
# Processing Record 34 of Set 2 | taoudenni
# Processing Record 35 of Set 2 | port lincoln
# Processing Record 36 of Set 2 | san policarpo
# Processing Record 37 of Set 2 | cherskiy
# Processing Record 38 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 39 of Set 2 | narsaq
# Processing Record 40 of Set 2 | vostok
# Processing Record 41 of Set 2 | luderitz
# Processing Record 42 of Set 2 | longyearbyen
# Processing Record 43 of Set 2 | dasoguz
# Processing Record 44 of Set 2 | alihe
# Processing Record 45 of Set 2 | udachnyy
# Processing Record 46 of Set 2 | pangkalanbuun
# Processing Record 47 of Set 2 | ahipara
# Processing Record 48 of Set 2 | turda
# Processing Record 49 of Set 2 | saint-philippe
# Processing Record 50 of Set 2 | plettenberg bay
# Processing Record 1 of Set 3 | namatanai
# Processing Record 2 of Set 3 | hofn
# Processing Record 3 of Set 3 | chittaurgarh
# Processing Record 4 of Set 3 | slatina
# Processing Record 5 of Set 3 | bathsheba
# Processing Record 6 of Set 3 | mangrol
# Processing Record 7 of Set 3 | laukaa
# Processing Record 8 of Set 3 | lasa
# Processing Record 9 of Set 3 | port shepstone
# Processing Record 10 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 3 | kloulklubed
# Processing Record 12 of Set 3 | kaduqli
# Processing Record 13 of Set 3 | mala tokmachka
# Processing Record 14 of Set 3 | port hedland
# Processing Record 15 of Set 3 | aleksandrov gay
# Processing Record 16 of Set 3 | port elizabeth
# Processing Record 17 of Set 3 | cidreira
# Processing Record 18 of Set 3 | iqaluit
# Processing Record 19 of Set 3 | marsa matruh
# Processing Record 20 of Set 3 | tiksi
# Processing Record 21 of Set 3 | atasu
# Processing Record 22 of Set 3 | asau
# Processing Record 23 of Set 3 | sinnamary
# Processing Record 24 of Set 3 | naze
# Processing Record 25 of Set 3 | ilabaya
# Processing Record 26 of Set 3 | eyl
# Processing Record 27 of Set 3 | imeni poliny osipenko
# Processing Record 28 of Set 3 | jinchang
# Processing Record 29 of Set 3 | ostrovnoy
# Processing Record 30 of Set 3 | edeia
# Processing Record 31 of Set 3 | leningradskiy
# Processing Record 32 of Set 3 | ponta do sol
# Processing Record 33 of Set 3 | san lazaro
# Processing Record 34 of Set 3 | sakata
# Processing Record 35 of Set 3 | pevek
# Processing Record 36 of Set 3 | marawi
# Processing Record 37 of Set 3 | nanortalik
# Processing Record 38 of Set 3 | takoradi
# Processing Record 39 of Set 3 | turayf
# Processing Record 40 of Set 3 | old town
# Processing Record 41 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 42 of Set 3 | torbay
# Processing Record 43 of Set 3 | emba
# Processing Record 44 of Set 3 | sobolevo
# Processing Record 45 of Set 3 | nemuro
# Processing Record 46 of Set 3 | andenes
# Processing Record 47 of Set 3 | maldonado
# Processing Record 48 of Set 3 | dolbeau
# City not found. Skipping...
# Processing Record 49 of Set 3 | matara
# Processing Record 50 of Set 3 | nizwa
# Processing Record 1 of Set 4 | kyshtovka
# Processing Record 2 of Set 4 | haibowan
# City not found. Skipping...
# Processing Record 3 of Set 4 | mar del plata
# Processing Record 4 of Set 4 | domoni
# Processing Record 5 of Set 4 | araouane
# Processing Record 6 of Set 4 | colchester
# Processing Record 7 of Set 4 | tasiilaq
# Processing Record 8 of Set 4 | sola
# Processing Record 9 of Set 4 | puerto ayacucho
# Processing Record 10 of Set 4 | cuiluan
# Processing Record 11 of Set 4 | sakakah
# Processing Record 12 of Set 4 | geraldton
# Processing Record 13 of Set 4 | anar darreh
# City not found. Skipping...
# Processing Record 14 of Set 4 | otane
# Processing Record 15 of Set 4 | bendigo
# Processing Record 16 of Set 4 | ulladulla
# Processing Record 17 of Set 4 | alta floresta
# Processing Record 18 of Set 4 | nova odesa
# Processing Record 19 of Set 4 | coruripe
# Processing Record 20 of Set 4 | saurimo
# Processing Record 21 of Set 4 | tabou
# Processing Record 22 of Set 4 | victoria
# Processing Record 23 of Set 4 | bambanglipuro
# Processing Record 24 of Set 4 | gat
# Processing Record 25 of Set 4 | chuy
# Processing Record 26 of Set 4 | veraval
# Processing Record 27 of Set 4 | banjar
# Processing Record 28 of Set 4 | codrington
# Processing Record 29 of Set 4 | khormuj
# City not found. Skipping...
# Processing Record 30 of Set 4 | chumikan
# Processing Record 31 of Set 4 | lesnoy
# Processing Record 32 of Set 4 | hambantota
# Processing Record 33 of Set 4 | skagastrond
# City not found. Skipping...
# Processing Record 34 of Set 4 | carandai
# Processing Record 35 of Set 4 | bundaberg
# Processing Record 36 of Set 4 | troitskoye
# Processing Record 37 of Set 4 | kalyazin
# Processing Record 38 of Set 4 | tucuman
# Processing Record 39 of Set 4 | kiruna
# Processing Record 40 of Set 4 | nizhnevartovsk
# Processing Record 41 of Set 4 | tura
# Processing Record 42 of Set 4 | kavaratti
# Processing Record 43 of Set 4 | wanning
# Processing Record 44 of Set 4 | jacareacanga
# Processing Record 45 of Set 4 | seoul
# Processing Record 46 of Set 4 | kropotkin
# Processing Record 47 of Set 4 | carquefou
# Processing Record 48 of Set 4 | ilulissat
# Processing Record 49 of Set 4 | sabang
# Processing Record 50 of Set 4 | ushumun
# Processing Record 1 of Set 5 | centenario do sul
# Processing Record 2 of Set 5 | bonavista
# Processing Record 3 of Set 5 | lichuan
# Processing Record 4 of Set 5 | seoni malwa
# Processing Record 5 of Set 5 | te anau
# Processing Record 6 of Set 5 | basco
# Processing Record 7 of Set 5 | lagoa
# Processing Record 8 of Set 5 | portsmouth
# Processing Record 9 of Set 5 | mikhaylovka
# Processing Record 10 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 11 of Set 5 | clyde river
# Processing Record 12 of Set 5 | montepuez
# Processing Record 13 of Set 5 | srandakan
# Processing Record 14 of Set 5 | roscrea
# Processing Record 15 of Set 5 | rurrenabaque
# Processing Record 16 of Set 5 | gumdag
# Processing Record 17 of Set 5 | damara
# Processing Record 18 of Set 5 | bo phloi
# Processing Record 19 of Set 5 | farakka
# Processing Record 20 of Set 5 | coquimbo
# Processing Record 21 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 5 | panjwin
# City not found. Skipping...
# Processing Record 23 of Set 5 | apeldoorn
# Processing Record 24 of Set 5 | richards bay
# Processing Record 25 of Set 5 | senneterre
# Processing Record 26 of Set 5 | mogadishu
# Processing Record 27 of Set 5 | sao joao da barra
# Processing Record 28 of Set 5 | tailai
# Processing Record 29 of Set 5 | saskylakh
# Processing Record 30 of Set 5 | sibolga
# Processing Record 31 of Set 5 | flinders
# Processing Record 32 of Set 5 | ippy
# Processing Record 33 of Set 5 | turukhansk
# Processing Record 34 of Set 5 | olafsvik
# Processing Record 35 of Set 5 | kieta
# Processing Record 36 of Set 5 | okhotsk
# Processing Record 37 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 38 of Set 5 | zavetnoye
# Processing Record 39 of Set 5 | cabrero
# Processing Record 40 of Set 5 | monte cristi
# City not found. Skipping...
# Processing Record 41 of Set 5 | punta arenas
# Processing Record 42 of Set 5 | bunol
# Processing Record 43 of Set 5 | dingle
# Processing Record 44 of Set 5 | vila franca do campo
# Processing Record 45 of Set 5 | deputatskiy
# Processing Record 46 of Set 5 | koslan
# Processing Record 47 of Set 5 | kingstown
# Processing Record 48 of Set 5 | yishui
# Processing Record 49 of Set 5 | berezovyy
# Processing Record 50 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 1 of Set 6 | dutse
# Processing Record 2 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 3 of Set 6 | grindavik
# Processing Record 4 of Set 6 | port blair
# Processing Record 5 of Set 6 | brewster
# Processing Record 6 of Set 6 | praia
# Processing Record 7 of Set 6 | okato
# Processing Record 8 of Set 6 | las palmas
# Processing Record 9 of Set 6 | labuan
# Processing Record 10 of Set 6 | mao
# Processing Record 11 of Set 6 | taldan
# Processing Record 12 of Set 6 | shurugwi
# Processing Record 13 of Set 6 | smoljan
# Processing Record 14 of Set 6 | gasa
# Processing Record 15 of Set 6 | termiz
# Processing Record 16 of Set 6 | miraflores
# Processing Record 17 of Set 6 | grand gaube
# Processing Record 18 of Set 6 | kodinsk
# Processing Record 19 of Set 6 | havelock
# Processing Record 20 of Set 6 | samarai
# Processing Record 21 of Set 6 | krylovskaya
# Processing Record 22 of Set 6 | edd
# Processing Record 23 of Set 6 | mollendo
# Processing Record 24 of Set 6 | nayoro
# Processing Record 25 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 26 of Set 6 | ola
# Processing Record 27 of Set 6 | doha
# Processing Record 28 of Set 6 | esperance
# Processing Record 29 of Set 6 | mount isa
# Processing Record 30 of Set 6 | mehamn
# Processing Record 31 of Set 6 | pedernales
# Processing Record 32 of Set 6 | sao luiz gonzaga
# Processing Record 33 of Set 6 | rondonopolis
# Processing Record 34 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 6 | gamba
# Processing Record 36 of Set 6 | strezhevoy
# Processing Record 37 of Set 6 | porto novo
# Processing Record 38 of Set 6 | lixourion
# Processing Record 39 of Set 6 | miyako
# Processing Record 40 of Set 6 | airai
# Processing Record 41 of Set 6 | bardiyah
# Processing Record 42 of Set 6 | kuching
# Processing Record 43 of Set 6 | qeshm
# Processing Record 44 of Set 6 | dekar
# Processing Record 45 of Set 6 | tugolesskiy bor
# Processing Record 46 of Set 6 | yicheng
# Processing Record 47 of Set 6 | buala
# Processing Record 48 of Set 6 | faya
# Processing Record 49 of Set 6 | shitanjing
# Processing Record 50 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 1 of Set 7 | samana
# Processing Record 2 of Set 7 | erenhot
# Processing Record 3 of Set 7 | loukhi
# Processing Record 4 of Set 7 | touros
# Processing Record 5 of Set 7 | ponta delgada
# Processing Record 6 of Set 7 | batemans bay
# Processing Record 7 of Set 7 | comrat
# Processing Record 8 of Set 7 | vao
# Processing Record 9 of Set 7 | raga
# Processing Record 10 of Set 7 | qingquan
# Processing Record 11 of Set 7 | batsfjord
# Processing Record 12 of Set 7 | sezze
# Processing Record 13 of Set 7 | ha tinh
# Processing Record 14 of Set 7 | requena
# Processing Record 15 of Set 7 | mielec
# Processing Record 16 of Set 7 | kostomuksha
# Processing Record 17 of Set 7 | vardo
# Processing Record 18 of Set 7 | coihaique
# Processing Record 19 of Set 7 | halifax
# Processing Record 20 of Set 7 | nishihara
# Processing Record 21 of Set 7 | malakal
# Processing Record 22 of Set 7 | palana
# Processing Record 23 of Set 7 | sisimiut
# Processing Record 24 of Set 7 | concordia
# Processing Record 25 of Set 7 | kruisfontein
# Processing Record 26 of Set 7 | dalby
# Processing Record 27 of Set 7 | nchelenge
# Processing Record 28 of Set 7 | rincon
# Processing Record 29 of Set 7 | grand-santi
# Processing Record 30 of Set 7 | garowe
# Processing Record 31 of Set 7 | el wasta
# City not found. Skipping...
# Processing Record 32 of Set 7 | salalah
# Processing Record 33 of Set 7 | beringovskiy
# Processing Record 34 of Set 7 | quatre cocos
# Processing Record 35 of Set 7 | kroya
# Processing Record 36 of Set 7 | mahuta
# Processing Record 37 of Set 7 | lorengau
# Processing Record 38 of Set 7 | ust-omchug
# Processing Record 39 of Set 7 | beidao
# Processing Record 40 of Set 7 | krzeszowice
# Processing Record 41 of Set 7 | kushmurun
# Processing Record 42 of Set 7 | cheuskiny
# City not found. Skipping...
# Processing Record 43 of Set 7 | jiddah
# City not found. Skipping...
# Processing Record 44 of Set 7 | barauli
# Processing Record 45 of Set 7 | bud
# Processing Record 46 of Set 7 | dalvik
# Processing Record 47 of Set 7 | zhanaozen
# Processing Record 48 of Set 7 | yagodnoye
# Processing Record 49 of Set 7 | along
# Processing Record 50 of Set 7 | saint-pierre
# Processing Record 1 of Set 8 | lincoln
# Processing Record 2 of Set 8 | zhigansk
# Processing Record 3 of Set 8 | yar-sale
# Processing Record 4 of Set 8 | locri
# Processing Record 5 of Set 8 | dubti
# Processing Record 6 of Set 8 | cayenne
# Processing Record 7 of Set 8 | hamilton
# Processing Record 8 of Set 8 | byron bay
# Processing Record 9 of Set 8 | belyy yar
# Processing Record 10 of Set 8 | imbituba
# Processing Record 11 of Set 8 | innisfail
# Processing Record 12 of Set 8 | pangnirtung
# Processing Record 13 of Set 8 | knysna
# Processing Record 14 of Set 8 | nantucket
# Processing Record 15 of Set 8 | klaksvik
# Processing Record 16 of Set 8 | catamarca
# Processing Record 17 of Set 8 | talnakh
# Processing Record 18 of Set 8 | castro
# Processing Record 19 of Set 8 | arman
# Processing Record 20 of Set 8 | ossora
# Processing Record 21 of Set 8 | bandarbeyla
# Processing Record 22 of Set 8 | otjimbingwe
# Processing Record 23 of Set 8 | biak
# Processing Record 24 of Set 8 | maraba
# Processing Record 25 of Set 8 | puerto leguizamo
# Processing Record 26 of Set 8 | truro
# Processing Record 27 of Set 8 | sao felix do xingu
# Processing Record 28 of Set 8 | san pedro de ycuamandiyu
# Processing Record 29 of Set 8 | heinola
# Processing Record 30 of Set 8 | eldorado
# Processing Record 31 of Set 8 | saldanha
# Processing Record 32 of Set 8 | florenville
# Processing Record 33 of Set 8 | gold coast
# Processing Record 34 of Set 8 | isangel
# Processing Record 35 of Set 8 | kamyshevatskaya
# Processing Record 36 of Set 8 | lovozero
# Processing Record 37 of Set 8 | westport
# Processing Record 38 of Set 8 | reinheim
# Processing Record 39 of Set 8 | yigou
# Processing Record 40 of Set 8 | urucara
# Processing Record 41 of Set 8 | nizhniy ingash
# Processing Record 42 of Set 8 | hosanagara
# Processing Record 43 of Set 8 | privolzhsk
# Processing Record 44 of Set 8 | padang
# Processing Record 45 of Set 8 | channel-port aux basques
# Processing Record 46 of Set 8 | dianopolis
# City not found. Skipping...
# Processing Record 47 of Set 8 | gondanglegi
# Processing Record 48 of Set 8 | peterhead
# Processing Record 49 of Set 8 | karamea
# City not found. Skipping...
# Processing Record 50 of Set 8 | thanh hoa
# Processing Record 1 of Set 9 | nampula
# Processing Record 2 of Set 9 | siocon
# Processing Record 3 of Set 9 | saint-leu
# Processing Record 4 of Set 9 | komsomolskiy
# Processing Record 5 of Set 9 | ginda
# Processing Record 6 of Set 9 | marevo
# Processing Record 7 of Set 9 | bilma
# Processing Record 8 of Set 9 | chaihe
# Processing Record 9 of Set 9 | portland
# Processing Record 10 of Set 9 | braunfels
# Processing Record 11 of Set 9 | jieshi
# Processing Record 12 of Set 9 | port-cartier
# Processing Record 13 of Set 9 | muros
# Processing Record 14 of Set 9 | jalu
# Processing Record 15 of Set 9 | labuhan
# Processing Record 16 of Set 9 | kemin
# Processing Record 17 of Set 9 | burnie
# Processing Record 18 of Set 9 | bongor
# Processing Record 19 of Set 9 | bilibino
# Processing Record 20 of Set 9 | someshwar
# Processing Record 21 of Set 9 | wilmington
# Processing Record 22 of Set 9 | itarema
# Processing Record 23 of Set 9 | derzhavinsk
# Processing Record 24 of Set 9 | acarau
# Processing Record 25 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 26 of Set 9 | solone
# Processing Record 27 of Set 9 | sur
# Processing Record 28 of Set 9 | trofors
# Processing Record 29 of Set 9 | barra do garcas
# Processing Record 30 of Set 9 | bulawayo
# Processing Record 31 of Set 9 | bushehr
# Processing Record 32 of Set 9 | ghanzi
# Processing Record 33 of Set 9 | zalesovo
# Processing Record 34 of Set 9 | antofagasta
# Processing Record 35 of Set 9 | kununurra
# Processing Record 36 of Set 9 | romny
# Processing Record 37 of Set 9 | emerald
# Processing Record 38 of Set 9 | broken hill
# Processing Record 39 of Set 9 | gizo
# Processing Record 40 of Set 9 | road town
# Processing Record 41 of Set 9 | mount gambier
# Processing Record 42 of Set 9 | mpika
# Processing Record 43 of Set 9 | warrnambool
# Processing Record 44 of Set 9 | impfondo
# Processing Record 45 of Set 9 | gulshat
# City not found. Skipping...
# Processing Record 46 of Set 9 | jiuquan
# Processing Record 47 of Set 9 | whakatane
# Processing Record 48 of Set 9 | obera
# Processing Record 49 of Set 9 | sindou
# Processing Record 50 of Set 9 | cascais
# Processing Record 1 of Set 10 | kysyl-syr
# Processing Record 2 of Set 10 | pokrovsk
# Processing Record 3 of Set 10 | sokoni
# Processing Record 4 of Set 10 | turinsk
# Processing Record 5 of Set 10 | polyarnyy
# Processing Record 6 of Set 10 | pringsewu
# Processing Record 7 of Set 10 | stephenville crossing
# Processing Record 8 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 9 of Set 10 | miri
# Processing Record 10 of Set 10 | coremas
# Processing Record 11 of Set 10 | moron
# Processing Record 12 of Set 10 | upernavik
# Processing Record 13 of Set 10 | lethem
# Processing Record 14 of Set 10 | kuusamo
# Processing Record 15 of Set 10 | gazli
# Processing Record 16 of Set 10 | sistranda
# Processing Record 17 of Set 10 | bonthe
# Processing Record 18 of Set 10 | adrar
# Processing Record 19 of Set 10 | nordborg
# Processing Record 20 of Set 10 | salaga
# Processing Record 21 of Set 10 | oranjestad
# Processing Record 22 of Set 10 | ayer itam
# City not found. Skipping...
# Processing Record 23 of Set 10 | saint-augustin
# Processing Record 24 of Set 10 | saryozek
# Processing Record 25 of Set 10 | atar
# Processing Record 26 of Set 10 | zelenoborskiy
# Processing Record 27 of Set 10 | banda aceh
# Processing Record 28 of Set 10 | sorland
# Processing Record 29 of Set 10 | kokkola
# Processing Record 30 of Set 10 | kaduna
# Processing Record 31 of Set 10 | fuerte olimpo
# Processing Record 32 of Set 10 | ust-nera
# Processing Record 33 of Set 10 | magadan
# Processing Record 34 of Set 10 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 35 of Set 10 | abu zabad
# Processing Record 36 of Set 10 | ulcinj
# Processing Record 37 of Set 10 | sri aman
# Processing Record 38 of Set 10 | shahr-e kord
# Processing Record 39 of Set 10 | artyom
# Processing Record 40 of Set 10 | shingu
# Processing Record 41 of Set 10 | uruzgan
# Processing Record 42 of Set 10 | anjozorobe
# Processing Record 43 of Set 10 | gwanda
# Processing Record 44 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 45 of Set 10 | sawtell
# Processing Record 46 of Set 10 | marv dasht
# City not found. Skipping...
# Processing Record 47 of Set 10 | phalaborwa
# Processing Record 48 of Set 10 | pinyug
# Processing Record 49 of Set 10 | narasannapeta
# Processing Record 50 of Set 10 | port moresby
# Processing Record 1 of Set 11 | skjervoy
# Processing Record 2 of Set 11 | nagato
# Processing Record 3 of Set 11 | mata
# Processing Record 4 of Set 11 | byumba
# Processing Record 5 of Set 11 | ambulu
# Processing Record 6 of Set 11 | sasaguri
# Processing Record 7 of Set 11 | muravlenko
# Processing Record 8 of Set 11 | dunda
# Processing Record 9 of Set 11 | esso
# Processing Record 10 of Set 11 | boa vista
# Processing Record 11 of Set 11 | lieksa
# Processing Record 12 of Set 11 | nhulunbuy
# Processing Record 13 of Set 11 | yumen
# Processing Record 14 of Set 11 | alyangula
# Processing Record 15 of Set 11 | mingshui
# Processing Record 16 of Set 11 | pathein
# Processing Record 17 of Set 11 | semiluki
# Processing Record 18 of Set 11 | dusetos
# Processing Record 19 of Set 11 | oranjemund
# Processing Record 20 of Set 11 | gambela
# Processing Record 21 of Set 11 | saint-joseph
# Processing Record 22 of Set 11 | bubaque
# Processing Record 23 of Set 11 | opuwo
# Processing Record 24 of Set 11 | kuala lipis
# Processing Record 25 of Set 11 | andros town
# Processing Record 26 of Set 11 | aksarka
# Processing Record 27 of Set 11 | anadyr
# Processing Record 28 of Set 11 | sena madureira
# Processing Record 29 of Set 11 | zyryanka
# Processing Record 30 of Set 11 | macenta
# Processing Record 31 of Set 11 | kanke
# Processing Record 32 of Set 11 | the valley
# Processing Record 33 of Set 11 | tessalit
# Processing Record 34 of Set 11 | pandan
# Processing Record 35 of Set 11 | dicabisagan
# Processing Record 36 of Set 11 | telimele
# Processing Record 37 of Set 11 | durango
# Processing Record 38 of Set 11 | yulara
# Processing Record 39 of Set 11 | podosinovets
# Processing Record 40 of Set 11 | itaituba
# Processing Record 41 of Set 11 | sarny
# Processing Record 42 of Set 11 | ipixuna
# Processing Record 43 of Set 11 | ginir
# Processing Record 44 of Set 11 | nanfeng
# Processing Record 45 of Set 11 | gelemso
# Processing Record 46 of Set 11 | abiy adi
# City not found. Skipping...
# Processing Record 47 of Set 11 | vilhena
# Processing Record 48 of Set 11 | xuddur
# Processing Record 49 of Set 11 | sept-iles
# Processing Record 50 of Set 11 | mitu
# Processing Record 1 of Set 12 | fukue
# Processing Record 2 of Set 12 | tsiroanomandidy
# Processing Record 3 of Set 12 | broome
# Processing Record 4 of Set 12 | agirish
# Processing Record 5 of Set 12 | panguna
# Processing Record 6 of Set 12 | najran
# Processing Record 7 of Set 12 | hami
# Processing Record 8 of Set 12 | soyo
# Processing Record 9 of Set 12 | ivanava
# Processing Record 10 of Set 12 | chikoy
# City not found. Skipping...
# Processing Record 11 of Set 12 | yurimaguas
# Processing Record 12 of Set 12 | namibe
# Processing Record 13 of Set 12 | saint anthony
# Processing Record 14 of Set 12 | fenoarivo
# Processing Record 15 of Set 12 | sambava
# Processing Record 16 of Set 12 | ngunguru
# Processing Record 17 of Set 12 | shirdi
# Processing Record 18 of Set 12 | inta
# Processing Record 19 of Set 12 | bayburt
# Processing Record 20 of Set 12 | kaniama
# Processing Record 21 of Set 12 | vestmannaeyjar
# Processing Record 22 of Set 12 | sao gabriel da cachoeira
# Processing Record 23 of Set 12 | karlstad
# Processing Record 24 of Set 12 | dhrangadhra
# Processing Record 25 of Set 12 | tungkang
# City not found. Skipping...
# Processing Record 26 of Set 12 | doctor juan leon mallorquin
# Processing Record 27 of Set 12 | goderich
# Processing Record 28 of Set 12 | galiwinku
# City not found. Skipping...
# Processing Record 29 of Set 12 | aktas
# Processing Record 30 of Set 12 | tommot
# Processing Record 31 of Set 12 | paamiut
# Processing Record 32 of Set 12 | aquidauana
# Processing Record 33 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 34 of Set 12 | omachi
# Processing Record 35 of Set 12 | navalmoral de la mata
# Processing Record 36 of Set 12 | mullaitivu
# City not found. Skipping...
# Processing Record 37 of Set 12 | dunedin
# Processing Record 38 of Set 12 | tuburan
# Processing Record 39 of Set 12 | thai binh
# Processing Record 40 of Set 12 | marsh harbour
# Processing Record 41 of Set 12 | roma
# Processing Record 42 of Set 12 | neuquen
# Processing Record 43 of Set 12 | gemona
# Processing Record 44 of Set 12 | pingliang
# Processing Record 45 of Set 12 | novoyegoryevskoye
# City not found. Skipping...
# Processing Record 46 of Set 12 | lannion
# Processing Record 47 of Set 12 | kargil
# Processing Record 48 of Set 12 | pasighat
# Processing Record 49 of Set 12 | palauig
# Processing Record 50 of Set 12 | walvis bay
# Processing Record 1 of Set 13 | vertou
# Processing Record 2 of Set 13 | laguna
# Processing Record 3 of Set 13 | freeport
# Processing Record 4 of Set 13 | cap malheureux
# Processing Record 5 of Set 13 | umm durman
# City not found. Skipping...
# Processing Record 6 of Set 13 | tyret pervaya
# Processing Record 7 of Set 13 | piney green
# Processing Record 8 of Set 13 | ranong
# Processing Record 9 of Set 13 | chekalin
# Processing Record 10 of Set 13 | rustenburg
# Processing Record 11 of Set 13 | axim
# Processing Record 12 of Set 13 | zharkovskiy
# Processing Record 13 of Set 13 | port macquarie
# Processing Record 14 of Set 13 | tafo
# Processing Record 15 of Set 13 | bazaliya
# Processing Record 16 of Set 13 | katherine
# Processing Record 17 of Set 13 | ayagoz
# Processing Record 18 of Set 13 | tupiza
# Processing Record 19 of Set 13 | molepolole
# Processing Record 20 of Set 13 | rayagada
# Processing Record 21 of Set 13 | vanimo
# Processing Record 22 of Set 13 | ialibu
# Processing Record 23 of Set 13 | vigeland
# Processing Record 24 of Set 13 | varkaus
# Processing Record 25 of Set 13 | neryungri
# Processing Record 26 of Set 13 | berlevag
# Processing Record 27 of Set 13 | marrakesh
# Processing Record 28 of Set 13 | nakhon phanom
# Processing Record 29 of Set 13 | buraydah
# Processing Record 30 of Set 13 | comodoro rivadavia
# Processing Record 31 of Set 13 | nouadhibou
# Processing Record 32 of Set 13 | ramanuj ganj
# Processing Record 33 of Set 13 | chegdomyn
# Processing Record 34 of Set 13 | gravdal
# Processing Record 35 of Set 13 | launceston
# Processing Record 36 of Set 13 | akdepe
# Processing Record 37 of Set 13 | yugo-kamskiy
# Processing Record 38 of Set 13 | chulym
# Processing Record 39 of Set 13 | khandagayty
# Processing Record 40 of Set 13 | ayan
# Processing Record 41 of Set 13 | gilgit
# Processing Record 42 of Set 13 | ambunti
# Processing Record 43 of Set 13 | beisfjord
# Processing Record 44 of Set 13 | tapaua
# City not found. Skipping...
# Processing Record 45 of Set 13 | leh
# Processing Record 46 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 47 of Set 13 | rio grande
# Processing Record 48 of Set 13 | vanavara
# Processing Record 49 of Set 13 | manzanares
# Processing Record 50 of Set 13 | itoman
# Processing Record 1 of Set 14 | kyzyl-suu
# Processing Record 2 of Set 14 | archidona
# Processing Record 3 of Set 14 | sorong
# Processing Record 4 of Set 14 | ipora
# Processing Record 5 of Set 14 | popondetta
# Processing Record 6 of Set 14 | micheweni
# Processing Record 7 of Set 14 | basoko
# Processing Record 8 of Set 14 | bereda
# Processing Record 9 of Set 14 | mindelo
# Processing Record 10 of Set 14 | rocha
# Processing Record 11 of Set 14 | rokytne
# Processing Record 12 of Set 14 | christchurch
# Processing Record 13 of Set 14 | los llanos de aridane
# Processing Record 14 of Set 14 | tual
# Processing Record 15 of Set 14 | san roque
# Processing Record 16 of Set 14 | menfi
# Processing Record 17 of Set 14 | cumaribo
# City not found. Skipping...
# Processing Record 18 of Set 14 | temaraia
# City not found. Skipping...
# Processing Record 19 of Set 14 | puerto narino
# Processing Record 20 of Set 14 | kuliyapitiya
# Processing Record 21 of Set 14 | bahir dar
# Processing Record 22 of Set 14 | chapais
# Processing Record 23 of Set 14 | quimper
# Processing Record 24 of Set 14 | beloha
# Processing Record 25 of Set 14 | dalbandin
# Processing Record 26 of Set 14 | berdigestyakh
# Processing Record 27 of Set 14 | framingham
# Processing Record 28 of Set 14 | jacqueville
# Processing Record 29 of Set 14 | lebu
# Processing Record 30 of Set 14 | kangundo
# Processing Record 31 of Set 14 | karasburg
# Processing Record 32 of Set 14 | presidencia roque saenz pena
# Processing Record 33 of Set 14 | bay roberts
# Processing Record 34 of Set 14 | kurilsk
# Processing Record 35 of Set 14 | khvastovichi
# Processing Record 36 of Set 14 | inhambane
# Processing Record 37 of Set 14 | pouembout
# Processing Record 38 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 39 of Set 14 | zambezi
# Processing Record 40 of Set 14 | teneguiban
# City not found. Skipping...
# Processing Record 41 of Set 14 | bentiu
# Processing Record 42 of Set 14 | keetmanshoop
# Processing Record 43 of Set 14 | pijino
# Processing Record 44 of Set 14 | verkhnevilyuysk
# Processing Record 45 of Set 14 | tamandare
# Processing Record 46 of Set 14 | kirkuk
# Processing Record 47 of Set 14 | corner brook
# Processing Record 48 of Set 14 | conde
# Processing Record 49 of Set 14 | plouzane
# Processing Record 50 of Set 14 | quthing
# Processing Record 1 of Set 15 | balkanabat
# Processing Record 2 of Set 15 | jiazi
# Processing Record 3 of Set 15 | honiton
# Processing Record 4 of Set 15 | uusikaupunki
# Processing Record 5 of Set 15 | jabiru
# City not found. Skipping...
# Processing Record 6 of Set 15 | panzhihua
# Processing Record 7 of Set 15 | wa
# City not found. Skipping...
# Processing Record 8 of Set 15 | xam nua
# Processing Record 9 of Set 15 | dzhusaly
# City not found. Skipping...
# Processing Record 10 of Set 15 | lata
# Processing Record 11 of Set 15 | protivin
# Processing Record 12 of Set 15 | netivot
# Processing Record 13 of Set 15 | tomigusuku
# Processing Record 14 of Set 15 | kongolo
# Processing Record 15 of Set 15 | zinder
# Processing Record 16 of Set 15 | sassandra
# Processing Record 17 of Set 15 | camacha
# Processing Record 18 of Set 15 | sirur
# Processing Record 19 of Set 15 | coolum beach
# Processing Record 20 of Set 15 | nalut
# Processing Record 21 of Set 15 | viedma
# Processing Record 22 of Set 15 | saint-francois
# Processing Record 23 of Set 15 | olinda
# Processing Record 24 of Set 15 | mazamari
# Processing Record 25 of Set 15 | vila velha
# Processing Record 26 of Set 15 | torbat-e jam
# Processing Record 27 of Set 15 | dwarka
# Processing Record 28 of Set 15 | itabaiana
# Processing Record 29 of Set 15 | cam ranh
# Processing Record 30 of Set 15 | thinadhoo
# Processing Record 31 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 32 of Set 15 | itarare
# Processing Record 33 of Set 15 | batagay-alyta
# Processing Record 34 of Set 15 | altay
# Processing Record 35 of Set 15 | holme
# Processing Record 36 of Set 15 | tazovskiy
# Processing Record 37 of Set 15 | belaya gora
# Processing Record 38 of Set 15 | niamey
# Processing Record 39 of Set 15 | belyy
# Processing Record 40 of Set 15 | dhidhdhoo
# Processing Record 41 of Set 15 | verkhnyaya inta
# Processing Record 42 of Set 15 | kirakira
# Processing Record 43 of Set 15 | evensk
# Processing Record 44 of Set 15 | concepcion
# Processing Record 45 of Set 15 | luganville
# Processing Record 46 of Set 15 | porto recanati
# Processing Record 47 of Set 15 | sokolow podlaski
# Processing Record 48 of Set 15 | kudahuvadhoo
# Processing Record 49 of Set 15 | korla
# Processing Record 50 of Set 15 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 16 | santa marta
# Processing Record 2 of Set 16 | cherdyn
# Processing Record 3 of Set 16 | rolandia
# Processing Record 4 of Set 16 | abha
# Processing Record 5 of Set 16 | tarudant
# City not found. Skipping...
# Processing Record 6 of Set 16 | bagotville
# Processing Record 7 of Set 16 | iquitos
# Processing Record 8 of Set 16 | ussel
# Processing Record 9 of Set 16 | tilichiki
# Processing Record 10 of Set 16 | srednekolymsk
# Processing Record 11 of Set 16 | mlyniv
# Processing Record 12 of Set 16 | carballo
# Processing Record 13 of Set 16 | loksa
# Processing Record 14 of Set 16 | rongcheng
# Processing Record 15 of Set 16 | san jose
# Processing Record 16 of Set 16 | harbin
# Processing Record 17 of Set 16 | ust-kishert
# Processing Record 18 of Set 16 | bartica
# Processing Record 19 of Set 16 | suez
# Processing Record 20 of Set 16 | ryotsu
# Processing Record 21 of Set 16 | nosy varika
# Processing Record 22 of Set 16 | ust-tsilma
# Processing Record 23 of Set 16 | verkhoyansk
# Processing Record 24 of Set 16 | sungairaya
# Processing Record 25 of Set 16 | kidal
# Processing Record 26 of Set 16 | bam
# Processing Record 27 of Set 16 | pontianak
# Processing Record 28 of Set 16 | northam
# Processing Record 29 of Set 16 | ribeirao branco
# Processing Record 30 of Set 16 | kindu
# Processing Record 31 of Set 16 | umarkot
# Processing Record 32 of Set 16 | suzhou
# Processing Record 33 of Set 16 | marystown
# Processing Record 34 of Set 16 | umzimvubu
# City not found. Skipping...
# Processing Record 35 of Set 16 | male
# Processing Record 36 of Set 16 | samfya
# Processing Record 37 of Set 16 | uniao da victoria
# City not found. Skipping...
# Processing Record 38 of Set 16 | acara
# Processing Record 39 of Set 16 | bolungarvik
# City not found. Skipping...
# Processing Record 40 of Set 16 | tacna
# Processing Record 41 of Set 16 | uarini
# Processing Record 42 of Set 16 | kolpashevo
# Processing Record 43 of Set 16 | yarqa
# Processing Record 44 of Set 16 | okha
# Processing Record 45 of Set 16 | sangar
# Processing Record 46 of Set 16 | suining
# Processing Record 47 of Set 16 | hare bay
# Processing Record 48 of Set 16 | gotsu
# Processing Record 49 of Set 16 | tumannyy
# City not found. Skipping...
# Processing Record 50 of Set 16 | shieli
# Processing Record 1 of Set 17 | ecija
# Processing Record 2 of Set 17 | bairiki
# Processing Record 3 of Set 17 | bitung
# Processing Record 4 of Set 17 | bosaso
# Processing Record 5 of Set 17 | ayorou
# Processing Record 6 of Set 17 | hun
# Processing Record 7 of Set 17 | mana
# Processing Record 8 of Set 17 | solsvik
# City not found. Skipping...
# Processing Record 9 of Set 17 | trinidad
# Processing Record 10 of Set 17 | ballina
# Processing Record 11 of Set 17 | tupancireta
# Processing Record 12 of Set 17 | belmonte
# Processing Record 13 of Set 17 | naron
# Processing Record 14 of Set 17 | vasudevanallur
# Processing Record 15 of Set 17 | griffith
# Processing Record 16 of Set 17 | ekibastuz
# Processing Record 17 of Set 17 | novyy urengoy
# Processing Record 18 of Set 17 | nova era
# Processing Record 19 of Set 17 | syamzha
# Processing Record 20 of Set 17 | wladyslawowo
# Processing Record 21 of Set 17 | temiscaming
# Processing Record 22 of Set 17 | tunduru
# City not found. Skipping...
# Processing Record 23 of Set 17 | menongue
# Processing Record 24 of Set 17 | tianpeng
# Processing Record 25 of Set 17 | karaton
# Processing Record 26 of Set 17 | prudentopolis
# Processing Record 27 of Set 17 | upington
# Processing Record 28 of Set 17 | puerto colombia
# Processing Record 29 of Set 17 | sorvag
# City not found. Skipping...
# Processing Record 30 of Set 17 | saint-georges
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(cities)
# Out:
# 830

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Hithadhoo  -0.6000   73.0833     81.34        73          25
# 1             Dikson  73.5069   80.5464    -22.67        98          70
# 2         Brokopondo   4.7500  -55.1667     77.02        88          65
# 3         Bredasdorp -34.5322   20.0403     62.80        66          92
# 4           Katsuura  35.1333  140.3000     65.30        68          80
# ..               ...      ...       ...       ...       ...         ...
# 762          Karaton  -6.3424  106.1045     86.07        58         100
# 763    Prudentopolis -25.2131  -50.9778     62.87        88         100
# 764         Upington -28.4478   21.2561     63.84        73         100
# 765  Puerto Colombia  10.9878  -74.9547     78.89        79         100
# 766    Saint-Georges  12.0564  -61.7485     80.28        78          40
#
#      Wind Speed Country Current Description
# 0         10.83      MV    scattered clouds
# 1          8.52      RU       broken clouds
# 2          8.14      SR       broken clouds
# 3          0.76      ZA     overcast clouds
# 4         10.85      JP       broken clouds
# ..          ...     ...                 ...
# 762        8.72      ID     overcast clouds
# 763        2.46      BR     overcast clouds
# 764        6.44      ZA          light rain
# 765       15.35      CO     overcast clouds
# 766       17.27      GD    scattered clouds
#
# [767 rows x 9 columns]

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0          Hithadhoo      MV  -0.6000   73.0833     81.34        73
# 1             Dikson      RU  73.5069   80.5464    -22.67        98
# 2         Brokopondo      SR   4.7500  -55.1667     77.02        88
# 3         Bredasdorp      ZA -34.5322   20.0403     62.80        66
# 4           Katsuura      JP  35.1333  140.3000     65.30        68
# ..               ...     ...      ...       ...       ...       ...
# 762          Karaton      ID  -6.3424  106.1045     86.07        58
# 763    Prudentopolis      BR -25.2131  -50.9778     62.87        88
# 764         Upington      ZA -28.4478   21.2561     63.84        73
# 765  Puerto Colombia      CO  10.9878  -74.9547     78.89        79
# 766    Saint-Georges      GD  12.0564  -61.7485     80.28        78
#
#      Cloudiness  Wind Speed Current Description
# 0            25       10.83    scattered clouds
# 1            70        8.52       broken clouds
# 2            65        8.14       broken clouds
# 3            92        0.76     overcast clouds
# 4            80       10.85       broken clouds
# ..          ...         ...                 ...
# 762         100        8.72     overcast clouds
# 763         100        2.46     overcast clouds
# 764         100        6.44          light rain
# 765         100       15.35     overcast clouds
# 766          40       17.27    scattered clouds
#
# [767 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "weather_database/cities.csv"


# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_Description")
